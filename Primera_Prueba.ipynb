# %% [markdown]
# <a href="https://colab.research.google.com/github/FranciscoParrenoTorres/CuttingProblem/blob/master/Primera_Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Así es como se hace un histograma

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

np.random.seed(42)
x = np.random.normal(size=1000)

plt.hist(x, density=True, bins=30)  # density=False would make counts
plt.ylabel('Probability')
plt.xlabel('Data');

# %% [markdown]
# Ahora con el paquete seaborn

# %%
import seaborn as sns
sns.displot(x, bins=82, kde=True);

# %%
import seaborn as sns
sns.displot(x, kde=True);

# %%
import pandas as pd
spanishPlayers = pd.Series(
    ['Casillas', 'Ramos', 'Pique', 'Puyol', 'Capdevila', 'Xabi Alonso', 'Busquets', 'Xavi Hernandez', 'Pedrito',
     'Iniesta', 'Villa'], index=[1, 15, 3, 5, 11, 14, 16, 8, 18, 6, 7])
print (spanishPlayers)
spanishPlayers
# Out:
# 1           Casillas
# 15             Ramos
# 3              Pique
# 5              Puyol
# 11         Capdevila
# 14       Xabi Alonso
# 16          Busquets
# 8     Xavi Hernandez
# 18           Pedrito
# 6            Iniesta
# 7              Villa
# dtype: object
